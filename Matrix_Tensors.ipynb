# %% [markdown]
# soal no 1

# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[20, 3, 7], [16, 6, 7]])
X
# Out:
# array([[20,  3,  7],
#        [16,  6,  7]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[0]
# Out:
# array([20,  3,  7])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1]
# Out:
# array([16,  6,  7])

# %% [markdown]
# soal no 2

# %%
import torch
import tensorflow

# %%
# ulangi soal nomor 1 menggunakan pytorch
X_pt = torch.tensor([[20, 3, 7], [16, 6, 7]])
X_pt
# Out:
# tensor([[20,  3,  7],
#         [16,  6,  7]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[0]
# Out:
# array([20,  3,  7])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1]
# Out:
# array([16,  6,  7])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
X_tf = tf.Variable([[20, 3, 7], [16, 6, 7]])
X_tf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_599/4230616478.py in <cell line: 0>()
#       1 # ulangi soal nomor 1 menggunakan tensorflow
# ----> 2 X_tf = tf.Variable([[20, 3, 7], [16, 6, 7]])
#       3 X_tf
#
# NameError: name 'tf' is not defined
