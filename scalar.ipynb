# %% [markdown]
# Soal no 1

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 91

# %%
# tampilkan tipe data dari x
type (x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 91

# %%
# tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
# jumlahkan x+y
x + y
# Out:
# 182

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.91

# %%
# jumlahkan x_float dengan y
x_float + y
# Out:
# 91.91

# %%
# tampilkan tipe data dari x_float
type (x_float)
# Out:
# float

# %% [markdown]
# Soal no 2

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(91, dtype=tf.int16)

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(91, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=91>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=182>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=182>

# %%
tf_sum.numpy()
# Out:
# np.int16(182)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(0.91, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=0.91015625>

# %% [markdown]
# Soal no 3

# %%
import torch

# %%
# buat variabel x_cl dan menyimpan suatu nilai
x_cl = torch.tensor(91)

# %%
# menampilkan type data
type (x_cl)
# Out:
# torch.Tensor

# %%
# buat variabel y_cl dan menyimpan suatu nilai
y_cl = torch.tensor(91)

# %%
# menampilkan type data
type (y_cl)
# Out:
# torch.Tensor

# %%
# jumlahkan
x_cl + y_cl
# Out:
# tensor(182)

# %%
# buat variabel x_float dan menyimpan suatu nilai
x_float = torch.tensor(70.3)

# %%
# jumlahkan x_float dengan y_cl
x_float + y_cl
# Out:
# tensor(161.3000)

# %%
# type data x_float
type (x_float)
# Out:
# torch.Tensor

# %%
x_cl.shape
# Out:
# torch.Size([])
